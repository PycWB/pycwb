# %%
from gwpy.timeseries import TimeSeries

framefile = '/Users/yumengxu/Project/Physics/cwb/pyBurst/tests/frames/S251014cn_H1.gwf'

timeseries = TimeSeries.read(framefile, 'H1:GDS-CALIB_STRAIN_CLEAN')
# trigger_time = 1420878141.222656

# start_time = trigger_time -  5
# end_time = trigger_time +  5
# detector = 'H1'
# timeseries = TimeSeries.fetch_open_data(detector, start_time, end_time, sample_rate=16384)

# %%
import sys
sys.path.insert(0, '/Users/yumengxu/Project/Physics/cwb/pyBurst')
from pycwb.types.time_series import TimeSeries as CwbTimeSeries
# Out:
# Welcome to JupyROOT 6.26/10
# Loading wavelet library
# Trying to load wavelet library from /Users/yumengxu/miniforge3/envs/pycwb_x64/lib/python3.11/site-packages/lib/wavelet.so
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).

# %%
# %matplotlib inline
timeseries.plot()
# Out:
# <Plot size 1200x400 with 1 Axes>
# <Plot size 1200x400 with 1 Axes>

# %%
timeseries.whiten().bandpass(100, 400).plot()
# Out:
# <Plot size 1200x400 with 1 Axes>
# <Plot size 1200x400 with 1 Axes>

# %%
cwb_timeseries = CwbTimeSeries.from_gwpy(timeseries)
cwb_whitened = cwb_timeseries.white(1, 0, 1 , 1)
# Out:
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 cwb_timeseries = CwbTimeSeries.from_gwpy(timeseries)
# ----> 2 cwb_whitened = cwb_timeseries.white(1, 0, 1 , 1)
#
# File ~/Project/Physics/cwb/pyBurst/pycwb/types/time_series.py:162, in TimeSeries.white(self, t, mode, oFFset, stride)
#     159     t = segT - 2.0 * oFFset
#     161 # compute offset (samples) and make it even (C++: if(offset&1) offset--)
# --> 162 offset = int(oFFset * rate + 0.5)
#     163 if offset & 1:
#     164     offset -= 1
#
# File ~/miniforge3/envs/pycwb_x64/lib/python3.11/site-packages/astropy/units/quantity.py:696, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     694     return NotImplemented
#     695 else:
# --> 696     raise e
#
# ...
