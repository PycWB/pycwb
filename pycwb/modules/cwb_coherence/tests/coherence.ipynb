# %% [markdown]
# ## Step 1: get the max energy from tf
#
# ```c
# alp += tf.maxEnergy(ts, wdm.wavelet, config.max_delay, up_n, config.pattern)
# ```
#
# maxEnergy contain the following steps:
#  - For each time slide in range [-K, K] (K = rate * dT) with step N, convert to TFMap and compute the pixels-wise max
#  - Combine all the max, then you can get the max energy

# %%
## Step 1: get the max energy from tf
# alp += tf.maxEnergy(ts, wdm.wavelet, config.max_delay, up_n, config.pattern)
##
# - xx.cpf(ts, ts.size() - k, 0, k);

## Step 2: 
# Eo = ROOT.threshold(tf_list, config.nIFO, config.segEdge, config.bpp, alp)

## Step 3: get the pixels with excess energy
#  pwc = ROOT.getNetworkPixels(config.nIFO, tf_list, nRMS_ws, 1,
#           config.segEdge, j, Eo, 1.0, [net.get_ifo(n).lagShift.data[j] for n in range(config.nIFO)])

## Step 4: cluster the pixels
# pwc.cluster(2, 3)
